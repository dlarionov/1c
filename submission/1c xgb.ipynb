# %% [markdown]
# # xgboost

# %%
import numpy as np
import pandas as pd
import gc
import pickle
import time

from xgboost import XGBRegressor

# %%
data = pd.read_pickle('feature_matrix.pickle')
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)
del data
gc.collect();

# %%
ts = time.time()

model = XGBRegressor(
    max_depth=7,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    colsample_bylevel=0.8, 
    subsample=0.8, 
    eta=0.3, 
    num_round=1000,
    seed=42)

model.fit(
    X_train, 
    Y_train, 
    eval_metric="rmse", 
    eval_set=[(X_valid, Y_valid)], 
    verbose=True, 
    early_stopping_rounds = 10)

time.time() - ts
# Out:
# [0]	validation_0-rmse:1.12493
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.09207
# [2]	validation_0-rmse:1.0599
# [3]	validation_0-rmse:1.03267
# [4]	validation_0-rmse:1.0108
# [5]	validation_0-rmse:0.991603
# [6]	validation_0-rmse:0.977159
# [7]	validation_0-rmse:0.964704
# [8]	validation_0-rmse:0.954495
# [9]	validation_0-rmse:0.944472
# [10]	validation_0-rmse:0.937878
# [11]	validation_0-rmse:0.932475
# [12]	validation_0-rmse:0.925853
# [13]	validation_0-rmse:0.920272
# [14]	validation_0-rmse:0.91701
# [15]	validation_0-rmse:0.914476
# [16]	validation_0-rmse:0.911774
# [17]	validation_0-rmse:0.909298
# [18]	validation_0-rmse:0.907289
# [19]	validation_0-rmse:0.905717
# [20]	validation_0-rmse:0.905032
# [21]	validation_0-rmse:0.903781
# [22]	validation_0-rmse:0.903704
# [23]	validation_0-rmse:0.903231
# [24]	validation_0-rmse:0.90234
# [25]	validation_0-rmse:0.90235
# [26]	validation_0-rmse:0.901907
# [27]	validation_0-rmse:0.901769
# [28]	validation_0-rmse:0.900822
# [29]	validation_0-rmse:0.901635
# [30]	validation_0-rmse:0.901379
# [31]	validation_0-rmse:0.90078
# [32]	validation_0-rmse:0.900106
# [33]	validation_0-rmse:0.899496
# [34]	validation_0-rmse:0.899141
# [35]	validation_0-rmse:0.89895
# [36]	validation_0-rmse:0.899026
# [37]	validation_0-rmse:0.89888
# [38]	validation_0-rmse:0.898999
# [39]	validation_0-rmse:0.898307
# [40]	validation_0-rmse:0.897816
# [41]	validation_0-rmse:0.897384
# [42]	validation_0-rmse:0.897038
# [43]	validation_0-rmse:0.896838
# [44]	validation_0-rmse:0.8969
# [45]	validation_0-rmse:0.897032
# [46]	validation_0-rmse:0.897109
# [47]	validation_0-rmse:0.897544
# [48]	validation_0-rmse:0.897397
# [49]	validation_0-rmse:0.897359
# [50]	validation_0-rmse:0.897015
# [51]	validation_0-rmse:0.896841
# [52]	validation_0-rmse:0.896774
# [53]	validation_0-rmse:0.896569
# [54]	validation_0-rmse:0.896607
# [55]	validation_0-rmse:0.895901
# [56]	validation_0-rmse:0.895307
# [57]	validation_0-rmse:0.894915
# [58]	validation_0-rmse:0.894104
# [59]	validation_0-rmse:0.894213
# [60]	validation_0-rmse:0.894189
# [61]	validation_0-rmse:0.893955
# [62]	validation_0-rmse:0.893717
# [63]	validation_0-rmse:0.893674
# [64]	validation_0-rmse:0.893607
# [65]	validation_0-rmse:0.893183
# [66]	validation_0-rmse:0.892813
# [67]	validation_0-rmse:0.892857
# [68]	validation_0-rmse:0.892781
# [69]	validation_0-rmse:0.892343
# [70]	validation_0-rmse:0.892148
# [71]	validation_0-rmse:0.89131
# [72]	validation_0-rmse:0.891596
# [73]	validation_0-rmse:0.891638
# [74]	validation_0-rmse:0.891439
# [75]	validation_0-rmse:0.891501
# [76]	validation_0-rmse:0.891454
# [77]	validation_0-rmse:0.891411
# [78]	validation_0-rmse:0.891121
# [79]	validation_0-rmse:0.891234
# [80]	validation_0-rmse:0.891132
# [81]	validation_0-rmse:0.891048
# [82]	validation_0-rmse:0.890837
# [83]	validation_0-rmse:0.890388
# [84]	validation_0-rmse:0.890335
# [85]	validation_0-rmse:0.889552
# [86]	validation_0-rmse:0.889657
# [87]	validation_0-rmse:0.88955
# [88]	validation_0-rmse:0.88948
# [89]	validation_0-rmse:0.889092
# [90]	validation_0-rmse:0.888869
# [91]	validation_0-rmse:0.88868
# [92]	validation_0-rmse:0.888744
# [93]	validation_0-rmse:0.888619
# [94]	validation_0-rmse:0.888051
# [95]	validation_0-rmse:0.888007
# [96]	validation_0-rmse:0.887922
# [97]	validation_0-rmse:0.887711
# [98]	validation_0-rmse:0.887668
# [99]	validation_0-rmse:0.887895
# 6092.679821014404

# %%
# model = pickle.load(open('xgb_model.pickle', 'rb'))

# %%
Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

# %%
pickle.dump(model, open('xgb_model.pickle', 'wb'))
pickle.dump(Y_pred, open('xgb_train.pickle', 'wb'))
pickle.dump(Y_test, open('xgb_test.pickle', 'wb'))

# %%
from xgboost import plot_importance

import matplotlib.pyplot as plt
# %matplotlib inline

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

plot_features(model, (12,42))

# %%
test = pd.read_csv('test.csv.gz', compression='gzip').set_index('ID')
submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('xgb_submission.csv', index=False)

# %% [markdown]
# * xgb 15 - LB: 0.96734 validation_0-rmse:0.882087
# * xgb 12 - LB: 0.96676 validation_0-rmse:0.887671
# * xgb 7 - LB: 0.98534 validation_0-rmse:0.887895
